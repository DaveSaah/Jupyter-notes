# %%
using Plots
# define the Lorenz attractor
Base.@kwdef mutable struct Lorenz
    dt::Float64 = 0.02
    σ::Float64 = 10
    ρ::Float64 = 28
    β::Float64 = 8/3
    x::Float64 = 1
    y::Float64 = 1
    z::Float64 = 1
end

function step!(l::Lorenz)
    dx = l.σ * (l.y - l.x)
    dy = l.x * (l.ρ - l.z) - l.y
    dz = l.x * l.y - l.β * l.z
    l.x += l.dt * dx
    l.y += l.dt * dy
    l.z += l.dt * dz
end

attractor = Lorenz()


# initialize a 3D plot with 1 empty series
plt = plot3d(
    1,
    xlim = (-30, 30),
    ylim = (-30, 30),
    zlim = (0, 60),
    title = "Lorenz Attractor",
    marker = 2,
)

# build an animated gif by pushing new points to the plot, saving every 10th frame
@gif for i=1:1500
    step!(attractor)
    push!(plt, attractor.x, attractor.y, attractor.z)
end every 10
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/hesed/Codes/Jupyter-notes/tmp.gif
# └ @ Plots /home/hesed/.julia/packages/Plots/FI0vT/src/animation.jl:114
# Plots.AnimatedGif("/home/hesed/Codes/Jupyter-notes/tmp.gif")

# %%
using Plots
# Out:
# WebIO._IJuliaInit()
# Plots.PlotlyJSBackend()

# %%
x = 1:10
# Out:
# 1:10

# %%
plotlyjs()
# Out:
# Plots.PlotlyJSBackend()

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
p1 = plot(x, x);
p2 = plot(x, x.^2);
p3 = plot(x, x.^3);
p4 = plot(x, x.^4);

# %%
plot(p1, p2, p3, p4, layout=(2,2), legend=false)
